# %%
import requests
import pandas as pd

# %%
api_key = 'key'

# %% [markdown]
# # 소환사 데이터 수집(Challenger, GrandMaster, Master)

# %%
def get_league_data(league):
    url = 'https://kr.api.riotgames.com/lol/league/v4/'+ league +'leagues/by-queue/RANKED_SOLO_5x5?api_key=' + api_key
    league_df = pd.DataFrame(requests.get(url).json())
    league_df.reset_index(inplace=True)#수집한 그마데이터 index정리
    league_entries_df = pd.DataFrame(dict(league_df['entries'])).T #dict구조로 되어 있는 entries컬럼 풀어주기
    league_df = pd.concat([league_df, league_entries_df], axis=1) #열끼리 결합
    league_df = league_df.drop(['index', 'queue', 'name', 'leagueId', 'entries', 'rank'], axis=1)
#     league_df.to_csv('./data/' + league + '.csv',index=False,encoding = 'cp949')#중간저장
    return league_df

# %%
chal_df = get_league_data('challenger')

# %%
gma_df = get_league_data('grandmaster')

# %%
ma_df = get_league_data('master')

# %%
chal_df
# Out:
#            tier freshBlood hotStreak inactive leaguePoints losses  \
# 0    CHALLENGER      False     False    False          902    227
# 1    CHALLENGER      False     False    False         1064    486
# 2    CHALLENGER      False     False    False          912    515
# 3    CHALLENGER      False      True    False         1112    565
# 4    CHALLENGER      False     False    False         1051    458
# 5    CHALLENGER      False     False    False          925    369
# 6    CHALLENGER       True     False    False          980    351
# 7    CHALLENGER      False     False    False         1074    754
# 8    CHALLENGER      False     False    False         1428    380
# 9    CHALLENGER       True     False    False          773   1012
# 10   CHALLENGER      False     False    False          947    209
# 11   CHALLENGER      False     False    False          887    477
# 12   CHALLENGER      False      True    False         1196    446
# 13   CHALLENGER      False     False    False         1032    329
# 14   CHALLENGER      False      True    False          875    222
# 15   CHALLENGER       True     False    False          850    990
# 16   CHALLENGER      False     False    False         1064    237
# 17   CHALLENGER       True     False    False          886    411
# 18   CHALLENGER      False     False    False         1045    764
# 19   CHALLENGER      False     False    False          863    231
# 20   CHALLENGER      False     False    False          839    151
# 21   CHALLENGER      False     False    False          872    517
# 22   CHALLENGER      False     False    False          848    569
# 23   CHALLENGER      False     False    False         1004    952
# 24   CHALLENGER       True     False    False          907    429
# 25   CHALLENGER      False     False    False          994   1281
# 26   CHALLENGER      False     False    False         1084    455
# 27   CHALLENGER      False     False    False          870    299
# 28   CHALLENGER      False      True    False         1009    235
# 29   CHALLENGER      False     False    False         1061    577
# ..          ...        ...       ...      ...          ...    ...
# 270  CHALLENGER      False     False    False          986    892
# 271  CHALLENGER      False     False    False         1310    917
# 272  CHALLENGER      False     False    False         1033    524
# 273  CHALLENGER       True     False    False          908    646
# 274  CHALLENGER      False      True    False          875     59
# 275  CHALLENGER       True      True    False          889    408
# 276  CHALLENGER       True      True    False          847     74
# 277  CHALLENGER      False     False    False          920    252
# 278  CHALLENGER      False      True    False         1103    504
# 279  CHALLENGER       True      True    False          842    943
# 280  CHALLENGER      False     False    False          887    217
# 281  CHALLENGER       True     False    False          977    920
# 282  CHALLENGER      False     False    False         1004   1004
# 283  CHALLENGER       True      True    False          846    314
# 284  CHALLENGER       True      True    False          835    270
# 285  CHALLENGER       True      True    False          860    828
# 286  CHALLENGER      False     False    False          873    282
# 287  CHALLENGER      False     False    False          992    289
# 288  CHALLENGER      False     False    False          956    710
# 289  CHALLENGER      False     False    False         1019   1125
# 290  CHALLENGER      False     False    False          841    266
# 291  CHALLENGER      False     False    False         1001   1247
# 292  CHALLENGER      False     False    False         1156    286
# 293  CHALLENGER       True      True    False          881    268
# 294  CHALLENGER      False     False    False          906    806
# 295  CHALLENGER       True      True    False          895     82
# 296  CHALLENGER      False      True    False          904    213
# 297  CHALLENGER      False      True    False          962    258
# 298  CHALLENGER      False     False    False         1185    390
# 299  CHALLENGER      False      True    False         1193    669
#
#                                            summonerId      summonerName  \
# 0      YAECZlT0gMbDeIkWn5VBAkVKULW9CzwqAep1fSNCPEmJyw              수기 김
# 1     mFnLYwWsxr9WTQbCW0Iu2BfhjSO9AvxU2cyJeiUjwOjR1R8            매일배고프다
# 2      2RcQJSiSixrSgy5PavxekdovvtEAb_LwH2bLha1ibfI0NA   SANDBOX GorillA
# 3     7uhS0N1zEjPJsO6SgU27CEfZ9950sL_d9X0rvhtNQhadiJg      SANDBOX Dove
# 4     EEsreOggxSovcxK4vwqWERDl6eFi7H6DNg0soeRazgNdTGA               타 잔
# 5     5LxG__6rPJioqy3nZSmUvFx1NXexrg1bEsgJTJOFd5e4Nek         야 핑 좀 꺼줄래
# 6     xtJBtIEe0wXs8dhNaEEPB3B1HCmCrUEfzbus4nqXxpGg51M           T1 Cuzz
# 7     GpbgHvXHm_ipUf2C04ftVDb_yASiJg5jgqpK0HJAkf18pto         Starryovo
# 8     S6M62Yd79A96eYZGLsJXJ0Q11IcSA1y9xqCPznuugZx4pHg            잇츠 낫배드
# 9     ZWWhJFXJmHRaUjBUKur3hUkMYRn9MFfgxLwoXzcGPCuVNw4     yiminggaoshou
# 10    dPC7hsi348Nk4KBqqloIM1W7egrYonoPYpF5Yyl9AMiKVX8          직스 좀 믿어줘
# 11    PlLEZIDSLyqhdKZmi-ShW5srR_mwKjwXlBSgxBPPT67dOao          루시안조이밴탈론
# 12    sEb8kfrXvZ7D72XdkBuIRWsjXNbKqRPguX1019Bln5Y4pgQ          FA Minit
# 13    Kh3MkXuFIa7YvbvPDcu7m8cnMduPzFi44De2yBJzF1HNXIY           Oct0ber
# 14     GWohQ1bwaml_F2Z5WYbgqayLZjWYGqQ45hDuAvs_k2hBbQ             Axiyo
# 15    C7G0Np2VUL38tSzPW0pf7vwLUjaZ67LPzsSn7lXSbTmJ-kA        d0 myself
# 16    q_dxAJB4XkO7cChpMYcauHDDMbim7SjN3O1UCtFmu113-o4          FA Chasy
# 17    Q7BdtlcQtNPByyts7lU2vRWNHOqstefbQN1qoygpIFM-4NA    ge ju tai xiao
# 18    9f6ie_dd2AyBeLav2PCN10mNzg82e1sVGb34aElRjjMfClQ               이도류
# 19    ksNhW5Mbg0hAc49kbVxgrAzMzisJyRI5MoprwzzvAStx5bk             TDBYY
# 20   EeHgEKZzMvVlLYcOt6Y2vLPfv6qS5y1xtBOMetoeRNL_wgF7            불면증환자임
# 21     hXSvmNvdsOHor5JKNryi_CiXYcgGdyKBEmfkAc-4e2mVVg               섶 훈
# 22    cfVglZqJYURFOghaxinj84CLplJNTl0RPEs9WIDa0Tm5ccE         AF BAekHO
# 23    gsl7UWGixZ7Zd9YcCmpIXKxDqGA7lAEz900geuaKVhc0wco            Kingen
# 24    OhJ5pFJe9dEcKsnGkRuuWgZ2pdktERwQYyMnUno5bfL89Fo      Gen G Rascal
# 25    -dreERWQlZjDYRr2pPGHVPd_e3YAfGclQtZwTzambcfPqv4          울부짖는마오카이
# 26    NwOkQ45lS74IYdW9WHp-lpsY-5epK7bDu5n747Mh8erR6mQ    SANDBOX Kabbie
# 27   xACfMtTBJ8mi93KCWfzdGCDpcSYMQNkAd68Wj71wla59ZYtp          huibuhui
# 28    xSKhzP4ct1v53IiICw0jh9Ug-ZuALs02X_Uze7O-L-HowEI             한푸 66
# 29    rtjB2YaLrLLJF6-dvZP1u8wpFzESWPsPJ2Gw3WquDsCPNw8           마스크 챙기자
# ..                                                ...               ...
# 270    IzJnF8YtP1lVzqbF24EmMhIG4-qv0KwLxPTaBkOuA3m-Hg               미쳐놈
# 271    CvcRWcvlTw0bTiNTV84rsmHmU31n-0LxQRWM8-S0GOxQFg          쪼렙이다말로하자
# 272   1iDC-XdmcaDfJN7Lb2TufuNc3Uy5ZChklW7kubnFYYSHv9o               카게게
# 273   Uww3SZwXwJQs16dtUJlBc2lprTqcCSU3lBQKtI5hmQHyQQw               꿀때지
# 274   cr5X_Za8VO4DC05-M8LOXpUKBIJ6CP85D3ge3C3a7FbTyLw       SoIo PIayer
# 275   jgh9V3g3KpjnNNBq1y78yJG5JtV0ns9jg7vqXMh9p_Xz36Q  TopJg DuoGameEND
# 276   fB4tbAMqIdCP_jMffnJFEHHJugfJhRErGNM7hZ2PA-x3kAc               순 의
# 277   n0Jzy7kBdno1A75IjRWoxzhNmXIX87EIIEdnXpKqxQMZcZI          See u AG
# 278   Xnlu-lwzjRoQH2PLMaoqCuFrAFCyayPDmyS5DJ9TfMXrdhg           FA Lava
# 279   -soc6dTL4Exl00OUz6fPHRVpNBu6rAr5P94oqJYkLrREgSE         더 간절한 이우진
# 280  fHRbLPLvLEjNnzFXNE13Ab34-adFqoQdHV9ZBP01tMRF2HjX             wehui
# 281   p8qTPxUqBztfYaFDeCsPSTC_yAcRQU_CkkqdyC2tn6cxwps             보충제내놔
# 282   AGX6iMUhcmV8HtgYNVg_uM3opRKM_kKw94rD5ARFK6wF0VI           BlGSHOT
# 283   vhNmSfcmZGpdVc04udOKf8kePKx0DbN5EAkNKZuIGMYCCuM            L1sure
# 284   EXB1eSYOJyzWcpBpENEyOUD3HzV9EF0O5cehLR2aFsEJnOE          Fzzzzzzz
# 285   pLwLnvbRltfIRTU8B1TCCXXMwXDe4iBMXZMwOw8s-JG61t8           DRX1200
# 286   pDwmc1_7TS4kW5AlBW4g3NCeRZLJfaF8pc9MR32d1GIP57Y            EM 강타자
# 287  EI7yhwVQzdnPB-CxjrjHpdZLVbJKQPJzqEDlPdGVE9GjszJ9         잘 되기를 모두가
# 288   Hw6JQvUJjxbFRLMFSToLeJKqfsc2LxiXMqDeR_wkVxbSMcc              NNGG
# 289    sB-lYlK1HjdAEmL1m9zY0f7MpxSD9JRk0bbuMP3Nek7RJg              탑 혜지
# 290    6NuOE1Zyb3dDaDu4FRQGHb20KSEynfP10Vs5pU_xtZaMBw             돌낳는남자
# 291   --F7hlRsH8sB-4cjRqXFJhZswAbYNc8lhVjtbQSF4H2kL64     Gen G Meaning
# 292   4OSSiuVysOWwKVM2GMpBQmIj6QDQnSy5mOp8Mth6LqHhTpk               윤용호
# 293   B_7CdnFLgttyazo-BKm5l-V7ZQXhQUZYxpS6bVMpcZLH--Y         베일에 싸인 사람
# 294   r2gHcktogMYrTunhEZTdT7uFTiU8xnoHg2BeQYCGUMqePj0   V5zhao874906839
# 295   6cA_0a6HkMin_hUupOHkbzaf4h89aX0oVs0lvRzRonS_oSg              Iava
# 296  5-cI5Bxl55x14OUOVZJPumH0j3L5gJCy9B3yxz7zb8giwNmg          YoneKing
# 297   HQi1T0KFY13QWSNsTbpFpryxAxkUvEtz4m6ffLL8qlyi1YU          말을잘못하는사람
# 298   h2Bh4icVdDBAxvYEXs9d2mIQOCupxaD5HXZUXCbWUfy3I_k          KT Rebel
# 299   ngPvbEsSjylhrUIZ4UlErzl14KQvXKYNm84d7BsQdASZH8U       Gen G Khael
#
#     veteran  wins
# 0     False   286
# 1     False   546
# 2      True   561
# 3      True   615
# 4      True   536
# 5     False   427
# 6     False   424
# 7     False   838
# 8      True   485
# 9     False  1091
# 10     True   284
# 11    False   532
# 12     True   523
# 13    False   385
# 14     True   230
# 15    False  1047
# 16    False   358
# 17    False   490
# 18     True   828
# 19     True   280
# 20     True   258
# 21    False   573
# 22    False   622
# 23     True   992
# 24    False   465
# 25    False  1352
# 26    False   515
# 27     True   399
# 28     True   365
# 29     True   632
# ..      ...   ...
# 270    True   971
# 271    True  1006
# 272    True   589
# 273   False   685
# 274   False   119
# 275   False   517
# 276   False   174
# 277    True   312
# 278   False   558
# 279   False   994
# 280   False   329
# 281   False   964
# 282   False  1040
# 283   False   364
# 284   False   307
# 285   False   832
# 286   False   307
# 287    True   350
# 288    True   850
# 289    True  1184
# 290   False   312
# 291    True  1296
# 292    True   362
# 293   False   372
# 294   False   867
# 295   False   161
# 296   False   323
# 297   False   319
# 298    True   463
# 299    True   783
#
# [300 rows x 10 columns]

# %% [markdown]
# # 유저별 고유 accountId 수집

# %%
def get_accountId(league_df):
    for i in range(len(league_df)):
        try:
            sohwan = 'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/' + league_df['summonerName'].iloc[i] + '?api_key=' + api_key 
            r = requests.get(sohwan)

            while r.status_code == 429:
                time.sleep(5)
                sohwan = 'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/' + league_df['summonerName'].iloc[i] + '?api_key=' + api_key 
                r = requests.get(sohwan)

            account_id = r.json()['accountId']
            league_df.iloc[i, -1] = account_id

        except:
            pass

# %%
get_accountId(chal_df)

# %%
chal_df.head()
# Out:
#          tier freshBlood hotStreak inactive leaguePoints losses  \
# 0  CHALLENGER      False     False    False          902    227
# 1  CHALLENGER      False     False    False         1064    486
# 2  CHALLENGER      False     False    False          912    515
# 3  CHALLENGER      False      True    False         1112    565
# 4  CHALLENGER      False     False    False         1051    458
#
#                                         summonerId     summonerName veteran  \
# 0   YAECZlT0gMbDeIkWn5VBAkVKULW9CzwqAep1fSNCPEmJyw             수기 김   False
# 1  mFnLYwWsxr9WTQbCW0Iu2BfhjSO9AvxU2cyJeiUjwOjR1R8           매일배고프다   False
# 2   2RcQJSiSixrSgy5PavxekdovvtEAb_LwH2bLha1ibfI0NA  SANDBOX GorillA    True
# 3  7uhS0N1zEjPJsO6SgU27CEfZ9950sL_d9X0rvhtNQhadiJg     SANDBOX Dove    True
# 4  EEsreOggxSovcxK4vwqWERDl6eFi7H6DNg0soeRazgNdTGA              타 잔    True
#
#                                                 wins
# 0       Fe7sW62-hqr-VJxxtNV8R6ZrfXWze1kUPiJl-FQHAFi5
# 1  i30QAALDUrwSriuiHTv7lOWb_SOXkvuf7vCW_KaQGlvC8W...
# 2       x8Dvxgu_lCqWhWZ9zI4J7gFsvTRXnxYZwftL0onkVPGP
# 3    C8rfCYMVOvkVRsUrefEAXJsvfswNgTv66Brt0uwgzUYB6x0
# 4    qBp8jNLncDxENX8EzBrQWrMh6yhhn8Goy-45PkVFbCN23BU
