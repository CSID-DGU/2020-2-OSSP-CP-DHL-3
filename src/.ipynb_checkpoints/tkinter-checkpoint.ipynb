# %%
import tkinter as tk
from tkinter import font as tkfont

# %%
x = 1024
y = 720
zoom_size = 24
subsample_size = 30

size = str(x) + "x" + str(y)
root = tk.Tk()
root.title('DHL')
root.geometry(size)
root.resizable(False, False)
frame = tk.Frame(root, bd = 5, bg='white', relief = 'groove')
frame.pack()

# %%
b_frame = tk.Frame(frame, width = x * 1, height = y * 0.166)
b_frame.grid(row = 0, column = 0, columnspan = 5)

b1_frame = tk.Frame(b_frame, width = x * 0.1, height = y * 0.166, bg='red')
b1_frame.pack(side = tk.LEFT)
image1 = tk.PhotoImage(file="../data/image/champion/가렌.png").zoom(zoom_size).subsample(subsample_size)
tk.Button(b1_frame, text=" ", image = image1).pack()

b2_frame = tk.Frame(b_frame, width = x * 0.1, height = y * 0.166,  bg='orange')
b2_frame.pack(side = tk.LEFT)
image2 = tk.PhotoImage(file="../data/image/champion/갈리오.png").zoom(zoom_size).subsample(subsample_size)
tk.Button(b2_frame, text=" ", image = image2).pack()

b3_frame = tk.Frame(b_frame, width = x * 0.1, height = y * 0.166,  bg='yellow')
b3_frame.pack(side = tk.LEFT)
image3 = tk.PhotoImage(file="../data/image/champion/갱플랭크.png").zoom(zoom_size).subsample(subsample_size)
tk.Button(b3_frame, text=" ", image = image3).pack()

b4_frame = tk.Frame(b_frame, width = x * 0.1, height = y * 0.166,  bg='green')
b4_frame.pack(side = tk.LEFT)
image4 = tk.PhotoImage(file="../data/image/champion/그라가스.png").zoom(zoom_size).subsample(subsample_size)
tk.Button(b4_frame, text=" ", image = image4).pack()

b5_frame = tk.Frame(b_frame, width = x * 0.1, height = y * 0.166,  bg='blue')
b5_frame.pack(side = tk.LEFT)
image5 = tk.PhotoImage(file="../data/image/champion/그레이브즈.png").zoom(zoom_size).subsample(subsample_size)
tk.Button(b5_frame, text=" ", image = image5).pack()

b6_frame = tk.Frame(b_frame, width = x * 0.1, height = y * 0.166,  bg='navy')
b6_frame.pack(side = tk.LEFT)
image6 = tk.PhotoImage(file="../data/image/champion/나르.png").zoom(zoom_size).subsample(subsample_size)
tk.Button(b6_frame, text=" ", image = image6).pack()

b7_frame = tk.Frame(b_frame, width = x * 0.1, height = y * 0.166,  bg='blue')
b7_frame.pack(side = tk.LEFT)
image7 = tk.PhotoImage(file="../data/image/champion/나미.png").zoom(zoom_size).subsample(subsample_size)
tk.Button(b7_frame, text=" ", image = image7).pack()

b8_frame = tk.Frame(b_frame, width = x * 0.1, height = y * 0.166,  bg='green')
b8_frame.pack(side = tk.LEFT)
image8 = tk.PhotoImage(file="../data/image/champion/나서스.png").zoom(zoom_size).subsample(subsample_size)
tk.Button(b8_frame, text=" ", image = image8).pack()

b9_frame = tk.Frame(b_frame, width = x * 0.1, height = y * 0.166,  bg='yellow')
b9_frame.pack(side = tk.LEFT)
image9 = tk.PhotoImage(file="../data/image/champion/노틸러스.png").zoom(zoom_size).subsample(subsample_size)
tk.Button(b9_frame, text=" ", image = image9).pack()

b10_frame = tk.Frame(b_frame, width = x * 0.1, height = y * 0.166,  bg='orange')
b10_frame.pack(side = tk.LEFT)
image10 = tk.PhotoImage(file="../data/image/champion/녹턴.png").zoom(zoom_size).subsample(subsample_size)
tk.Button(b10_frame, text=" ", image = image10).pack()

# %%
l1_frame = tk.Frame(frame, width = x * 0.2, height = y * 0.166, bg='orange')
l1_frame.grid(row = 1, column = 0)

l2_frame = tk.Frame(frame, width = x * 0.2, height = y * 0.166, bg='yellow')
l2_frame.grid(row = 2, column = 0)

l3_frame = tk.Frame(frame, width = x * 0.2, height = y * 0.166, bg='green')
l3_frame.grid(row = 3, column = 0)

l4_frame = tk.Frame(frame, width = x * 0.2, height = y * 0.168, bg='blue')
l4_frame.grid(row = 4, column = 0)

l5_frame = tk.Frame(frame, width = x * 0.2, height = y * 0.166, bg='red')
l5_frame.grid(row = 5, column = 0)

# %%
m_frame = tk.Frame(frame, width = x * 0.6, height = y * 0.668, bg='purple')
m_frame.grid(row = 1, column = 1, rowspan = 4)

# %%
r1_frame = tk.Frame(frame, width = x * 0.2, height = y * 0.166, bg='orange')
r1_frame.grid(row = 1, column = 4)

r2_frame = tk.Frame(frame, width = x * 0.2, height = y * 0.166, bg='yellow')
r2_frame.grid(row = 2, column = 4)

r3_frame = tk.Frame(frame, width = x * 0.2, height = y * 0.166, bg='green')
r3_frame.grid(row = 3, column = 4)

r4_frame = tk.Frame(frame, width = x * 0.2, height = y * 0.168, bg='blue')
r4_frame.grid(row = 4, column = 4)

r5_frame = tk.Frame(frame, width = x * 0.2, height = y * 0.166, bg='red')
r5_frame.grid(row = 5, column = 4)

option_frame = tk.Frame(frame, width = x * 0.6, height = y * 0.166, bg='white')
option_frame.grid(row = 5, column = 1)

line_frame = tk.Frame(option_frame, width = x * 0.61, height = y * 0.066, bg = "orange")
line_frame.grid(row = 0, column = 0)

# %%
CheckVariety=tk.IntVar()
top_btn = tk.Radiobutton(line_frame, text="탑", value = 1, width = 10, height = 3, variable=CheckVariety, activebackground="blue").pack(side=tk.LEFT)
jg_btn = tk.Radiobutton(line_frame, text="정글", value = 2, width = 10, height = 3, variable=CheckVariety, activebackground="blue").pack(side=tk.LEFT)
mid_btn = tk.Radiobutton(line_frame, text="미드", value = 3, width = 10, height = 3, variable=CheckVariety, activebackground="blue").pack(side=tk.LEFT)
ad_btn = tk.Radiobutton(line_frame, text="원딜", value = 4, width = 10, height = 3, variable=CheckVariety, activebackground="blue").pack(side=tk.LEFT)
sp_btn = tk.Radiobutton(line_frame, text="서폿", value = 5, width = 10, height = 3, variable=CheckVariety, activebackground="blue").pack(side=tk.LEFT)

# %%
choice_frame = tk.Frame(option_frame, width = x * 0.6, height = y * 0.1, bg = "yellow")
choice_frame.grid(row = 1, column = 0)

rec_frame = tk.Frame(choice_frame, width = x * 0.6 * 0.33, height = y * 0.1, bg = "green")
rec_frame.grid(row = 0, column = 0)
button_recommend = tk.Button(rec_frame, width = 21, height = 3, text="추천받기")
button_recommend.pack()

select_frame = tk.Frame(choice_frame, width = x * 0.6 * 0.34, height = y * 0.1, bg = "yellow")
select_frame.grid(row = 0, column = 1)
button_pick = tk.Button(select_frame, width = 26, height = 3, text="선택하기")
button_pick.pack()

rec_text_frame = tk.Frame(choice_frame, width = x * 0.6 * 0.328, height = y * 0.1, bg = "navy")
rec_text_frame.grid(row = 0, column = 2)
button_request = tk.Button(rec_text_frame, width = 21, height = 3, text="추천챔피언")
button_request.pack()

# %%
champion_list = ['가렌','갈리오','갱플랭크','그라가스','그레이브즈','나르','나미','나서스','노틸러스','녹턴','누누','니달리','니코','다리우스','다이애나','드레이븐','라이즈','라칸','람머스','럭스','럼블','레넥톤','레오나','렉사이','렝가','루시안','룰루','르블랑','리 신','리븐','리산드라','릴리아','마스터 이','마오카이','말자하','말파이트','모데카이저','모르가나','문도 박사','미스 포츈','바드','바루스','바이','베이가','베인','벨코즈','볼리베어','브라움','브랜드','블라디미르','블리츠크랭크','빅토르','뽀삐','사미라','사이온','사일러스','샤코','세나','세라핀','세주아니','세트','소나','소라카','쉔','쉬바나','스웨인','스카너','시비르','신 짜오','신드라','신지드','쓰레쉬','아리','아무무','아우렐리온 솔','아이번','아지르','아칼리','아트록스','아펠리오스','알리스타','애니','애니비아','애쉬','야스오','에코', '엘리스','오공','오른','오리아나','올라프','요네','요릭','우디르','우르곳','워윅','유미','이렐리아','이블린','이즈리얼','일라오이','자르반 4세','자야','자이라','자크','잔나', '잭스', '제드', '제라스', '제이스', '조이', '직스', '진', '질리언', '징크스', '초가스', '카르마', '카밀', '카사딘', '카서스', '카시오페아', '카이사', '카직스', '카타리나', '칼리스타', '케넨', '케이틀린', '케인', '케일', '코그모', '코르키', '퀸', '클레드', '키아나', '킨드레드', '타릭', '탈론', '탈리야', '탐 켄치', '트런들', '트리스타나', '트린다미어','트위스티드 페이트', '트위치', '티모', '파이크', '판테온', '피들스틱', '피오라', '피즈', '하이머딩거', '헤카림']

image_m = []
button_m = []

for i in range(len(champion_list)):
    image_m.append(tk.PhotoImage(file='../data/image/champion/'+champion_list[i] + '.png').zoom(zoom_size - 2).subsample(subsample_size))

canvas = tk.Canvas(m_frame)
canvas.grid(row=0, column=0, sticky="news")

scroll = tk.Scrollbar(m_frame, orient="vertical", command=canvas.yview)
scroll.grid(sticky='news', row=0, column=7)

canvas.configure(yscrollcommand=scroll.set)

frame_buttons = tk.Frame(canvas, bg="white")
canvas.create_window((0, 0), window=frame_buttons, anchor='nw')
selected = 0

for i in range(len(champion_list)):
    button_m.append(tk.Button(frame_buttons, image=image_m[i]))
    button_m[i].grid(row=int(i / 6), column=int(i % 6))

frame_buttons.update_idletasks()

firstcolumns_width = sum([button_m[i].winfo_width() for i in range(0, 6)])
firstrows_height = sum([button_m[i].winfo_height() for i in range(0, 5)])
m_frame.config(width=firstcolumns_width + scroll.winfo_width(), height=firstrows_height)
canvas.configure(width=firstcolumns_width + scroll.winfo_width(), height=firstrows_height)


canvas.config(scrollregion=canvas.bbox("all"))

# %%
def click_champion(num):
    for i in range(len(champion_list)):
        if i == num:
            continue
        else:
            button_m[i].config(state = tk.DISABLED)
            ## 챔피언 1개 선택시 다른 챔피언이 눌리지 않도록 비활성화.

# %%
button_m[0].config(command =lambda: click_champion(0))
button_m[1].config(command =lambda: click_champion(1))
button_m[2].config(command =lambda: click_champion(2))
button_m[3].config(command =lambda: click_champion(3))
button_m[4].config(command =lambda: click_champion(4))
button_m[5].config(command =lambda: click_champion(5))
button_m[6].config(command =lambda: click_champion(6))
button_m[7].config(command =lambda: click_champion(7))
button_m[8].config(command =lambda: click_champion(8))
button_m[9].config(command =lambda: click_champion(9))
button_m[10].config(command =lambda: click_champion(10))
button_m[11].config(command =lambda: click_champion(11))
button_m[12].config(command =lambda: click_champion(12))
button_m[13].config(command =lambda: click_champion(13))
button_m[14].config(command =lambda: click_champion(14))
button_m[15].config(command =lambda: click_champion(15))
button_m[16].config(command =lambda: click_champion(16))
button_m[17].config(command =lambda: click_champion(17))
button_m[18].config(command =lambda: click_champion(18))
button_m[19].config(command =lambda: click_champion(19))
button_m[20].config(command =lambda: click_champion(20))
button_m[21].config(command =lambda: click_champion(21))
button_m[22].config(command =lambda: click_champion(22))
button_m[23].config(command =lambda: click_champion(23))
button_m[24].config(command =lambda: click_champion(24))
button_m[25].config(command =lambda: click_champion(25))
button_m[26].config(command =lambda: click_champion(26))
button_m[27].config(command =lambda: click_champion(27))
button_m[28].config(command =lambda: click_champion(28))
button_m[29].config(command =lambda: click_champion(29))
button_m[30].config(command =lambda: click_champion(30))
button_m[31].config(command =lambda: click_champion(31))
button_m[32].config(command =lambda: click_champion(32))
button_m[33].config(command =lambda: click_champion(33))
button_m[34].config(command =lambda: click_champion(34))
button_m[35].config(command =lambda: click_champion(35))
button_m[36].config(command =lambda: click_champion(36))
button_m[37].config(command =lambda: click_champion(37))
button_m[38].config(command =lambda: click_champion(38))
button_m[39].config(command =lambda: click_champion(39))
button_m[40].config(command =lambda: click_champion(40))
button_m[41].config(command =lambda: click_champion(41))
button_m[42].config(command =lambda: click_champion(42))
button_m[43].config(command =lambda: click_champion(43))
button_m[44].config(command =lambda: click_champion(44))
button_m[45].config(command =lambda: click_champion(45))
button_m[46].config(command =lambda: click_champion(46))
button_m[47].config(command =lambda: click_champion(47))
button_m[48].config(command =lambda: click_champion(48))
button_m[49].config(command =lambda: click_champion(49))
button_m[50].config(command =lambda: click_champion(50))
button_m[51].config(command =lambda: click_champion(51))
button_m[52].config(command =lambda: click_champion(52))
button_m[53].config(command =lambda: click_champion(53))
button_m[54].config(command =lambda: click_champion(54))
button_m[55].config(command =lambda: click_champion(55))
button_m[56].config(command =lambda: click_champion(56))
button_m[57].config(command =lambda: click_champion(57))
button_m[58].config(command =lambda: click_champion(58))
button_m[59].config(command =lambda: click_champion(59))
button_m[60].config(command =lambda: click_champion(60))
button_m[61].config(command =lambda: click_champion(61))
button_m[62].config(command =lambda: click_champion(62))
button_m[63].config(command =lambda: click_champion(63))
button_m[64].config(command =lambda: click_champion(64))
button_m[65].config(command =lambda: click_champion(65))
button_m[66].config(command =lambda: click_champion(66))
button_m[67].config(command =lambda: click_champion(67))
button_m[68].config(command =lambda: click_champion(68))
button_m[69].config(command =lambda: click_champion(69))
button_m[70].config(command =lambda: click_champion(70))
button_m[71].config(command =lambda: click_champion(71))
button_m[72].config(command =lambda: click_champion(72))
button_m[73].config(command =lambda: click_champion(73))
button_m[74].config(command =lambda: click_champion(74))
button_m[75].config(command =lambda: click_champion(75))
button_m[76].config(command =lambda: click_champion(76))
button_m[77].config(command =lambda: click_champion(77))
button_m[78].config(command =lambda: click_champion(78))
button_m[79].config(command =lambda: click_champion(79))
button_m[80].config(command =lambda: click_champion(80))
button_m[81].config(command =lambda: click_champion(81))
button_m[82].config(command =lambda: click_champion(82))
button_m[83].config(command =lambda: click_champion(83))
button_m[84].config(command =lambda: click_champion(84))
button_m[85].config(command =lambda: click_champion(85))
button_m[86].config(command =lambda: click_champion(86))
button_m[87].config(command =lambda: click_champion(87))
button_m[88].config(command =lambda: click_champion(88))
button_m[89].config(command =lambda: click_champion(89))
button_m[90].config(command =lambda: click_champion(90))
button_m[91].config(command =lambda: click_champion(91))
button_m[92].config(command =lambda: click_champion(92))
button_m[93].config(command =lambda: click_champion(93))
button_m[94].config(command =lambda: click_champion(94))
button_m[95].config(command =lambda: click_champion(95))
button_m[96].config(command =lambda: click_champion(96))
button_m[97].config(command =lambda: click_champion(97))
button_m[98].config(command =lambda: click_champion(98))
button_m[99].config(command =lambda: click_champion(99))
button_m[100].config(command =lambda: click_champion(100))
button_m[101].config(command =lambda: click_champion(101))
button_m[102].config(command =lambda: click_champion(102))
button_m[103].config(command =lambda: click_champion(103))
button_m[104].config(command =lambda: click_champion(104))
button_m[105].config(command =lambda: click_champion(105))
button_m[106].config(command =lambda: click_champion(106))
button_m[107].config(command =lambda: click_champion(107))
button_m[108].config(command =lambda: click_champion(108))
button_m[109].config(command =lambda: click_champion(109))
button_m[110].config(command =lambda: click_champion(110))
button_m[111].config(command =lambda: click_champion(111))
button_m[112].config(command =lambda: click_champion(112))
button_m[113].config(command =lambda: click_champion(113))
button_m[114].config(command =lambda: click_champion(114))
button_m[115].config(command =lambda: click_champion(115))
button_m[116].config(command =lambda: click_champion(116))
button_m[117].config(command =lambda: click_champion(117))
button_m[118].config(command =lambda: click_champion(118))
button_m[119].config(command =lambda: click_champion(119))
button_m[120].config(command =lambda: click_champion(120))
button_m[121].config(command =lambda: click_champion(121))
button_m[122].config(command =lambda: click_champion(122))
button_m[123].config(command =lambda: click_champion(123))
button_m[124].config(command =lambda: click_champion(124))
button_m[125].config(command =lambda: click_champion(125))
button_m[126].config(command =lambda: click_champion(126))
button_m[127].config(command =lambda: click_champion(127))
button_m[128].config(command =lambda: click_champion(128))
button_m[129].config(command =lambda: click_champion(129))
button_m[130].config(command =lambda: click_champion(130))
button_m[131].config(command =lambda: click_champion(131))
button_m[132].config(command =lambda: click_champion(132))
button_m[133].config(command =lambda: click_champion(133))
button_m[134].config(command =lambda: click_champion(134))
button_m[135].config(command =lambda: click_champion(135))
button_m[136].config(command =lambda: click_champion(136))
button_m[137].config(command =lambda: click_champion(137))
button_m[138].config(command =lambda: click_champion(138))
button_m[139].config(command =lambda: click_champion(139))
button_m[140].config(command =lambda: click_champion(140))
button_m[141].config(command =lambda: click_champion(141))
button_m[142].config(command =lambda: click_champion(142))
button_m[143].config(command =lambda: click_champion(143))
button_m[144].config(command =lambda: click_champion(144))
button_m[145].config(command =lambda: click_champion(145))
button_m[146].config(command =lambda: click_champion(146))
button_m[147].config(command =lambda: click_champion(147))
button_m[148].config(command =lambda: click_champion(148))
button_m[149].config(command =lambda: click_champion(149))
button_m[150].config(command =lambda: click_champion(150))
button_m[151].config(command =lambda: click_champion(151))

# %%
def click_pick():
    for i in range(len(champion_list)):
        button_m[i].config(state = tk.ACTIVE)
    ## pick 확정시 다른 챔피언 선택 가능하도록 다시 활성화.
        
button_pick.config(command=lambda: click_pick())

# %%
root.mainloop()
